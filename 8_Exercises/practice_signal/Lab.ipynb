# %% [markdown]
# # Signals

# %% [markdown]
# ## Lab 01 - Intro to signal processing
# * Plot $x(t) = 2e^{j2 \pi t}$

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')
t = np.arange(-1*np.pi,1*np.pi,0.01)
complex_expo = 2*np.e**(1j*2*np.pi*t)
real = np.real(complex_expo)
imag = np.imag(complex_expo)

ax.plot3D(t,real,imag)
ax.set_xlabel('t ')
ax.set_ylabel('real ')
ax.set_zlabel('imag ')

plt.show()

plt.plot(t,real,label="real")
plt.plot(t,imag,label="imag")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Periodic or aperiodic?
# * $x_1(t) = sin(\frac{2 \pi  }{ 3}t) + sin(3 \pi t)  $ -> คาบ
# * $x_2(t) = sin(\frac{2 \pi  }{ 3}t) + sin(3 t)  $ -> ไม่เป็นคาบ

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(-10,10,0.01)
x1 = np.sin(2*np.pi/3*t) + np.sin(3*np.pi*t)
x2 = np.sin(2*np.pi/3*t) + np.sin(3*t)


plt.plot(t,x1)
plt.show()
plt.plot(t,x2)
plt.show()

# %% [markdown]
# ## Lab 02 - Convolution

# %%
# Exercise 2.1
import numpy as np
import matplotlib.pyplot as plt

x1 = [1,3,-1,-2] # M = 4
h1 = [1,2,0,-1,1] # N = 5
y1 = np.convolve(h1, x1) # M+N-1 ตัว 8 ตัว
n = np.arange(0,len(y1),1)

plt.stem(n,y1,'r',markerfmt='or')
plt.show()

# %%
# Exercise 2.1
import numpy as np
import matplotlib.pyplot as plt

x1 = [0,0,1,3,-1,-2] # M = 4
h1 = [0,0,0,1,2,0,-1,1] # N = 5
y1 = np.convolve(h1, x1) # M+N-1 ตัว 8 ตัว
n = np.arange(0,len(y1),1)

plt.stem(n,y1,'r',markerfmt='or')
plt.show()

# %%
# Exercise 2.2
import numpy as np
import matplotlib.pyplot as plt

alpha = 1/2
beta = 1/3

n = np.arange(0,5,1)
x_n = alpha**n
h_n = beta**n
plt.stem(n,x_n,'b',markerfmt='ob')
plt.stem(n,h_n,'r',markerfmt='or')
plt.show()

y = beta**n * (1- (alpha/beta)**(n+1))/(1-alpha/beta)
plt.stem(n,y,'g',markerfmt='og'),plt.title("y[n]")
plt.show()

# %%
# Inclass
import numpy as np
import matplotlib.pyplot as plt

x1 = [1,3,1] # M = 4
h1 = [1,3,1] # N = 5
y1 = np.convolve(h1, x1) # M+N-1 ตัว 8 ตัว
n = np.arange(0,len(y1),1)

plt.stem(n,y1,'r',markerfmt='or')
plt.show()

# %%
# Inclass
import numpy as np
import matplotlib.pyplot as plt

x1 = [3,2,1] # M = 4
h1 = [3,2,1] # N = 5
y1 = np.convolve(h1, x1) # M+N-1 ตัว 8 ตัว
n = np.arange(0,len(y1),1)

plt.stem(n,y1,'r',markerfmt='or')
plt.show()

# %% [markdown]
# ## Lab 03 - Convolution & Fourier Series

# %% [markdown]
# 2. $f_2(t) * g_2(t)$

# %%
from matplotlib import legend
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(-1.5,0,0.01)
fg = _______________________
plt.plot(t,fg,label="1.25/pi * (1-sin (pi t))")


t2 = np.arange(0,0.5,0.01)
fg2 = _______________________
plt.plot(t2,fg2,label="1.25/pi * (cos (pi t) -sin (pi t))")


t3 = np.arange(0.5,2,0.01)
fg3 = _______________________
plt.plot(t3,fg3,label="1.25/pi * (cos (pi t))")

plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# 4. Fourier Series Representation

# %%
import matplotlib.pyplot as plt
import numpy as np

r = np.arange(-1,1,0.01)

t_0 = np.arange(-3,3,0.01)
x_t  = np.tile(r,3)
plt.plot(t_0,x_t)
plt.show()

# %% [markdown]
# * Plot line spectra

# %%
# Plot line spectra
from matplotlib import legend
import matplotlib.pyplot as plt
import numpy as np

k = np.arange(-10,11,1, dtype=float)
a_k = 1j / (k * np.pi) * np.cos(k*np.pi)
a_k[10] = 0
plt.stem(k,np.abs(a_k)); plt.title("|a_k|")
plt.show()

plt.stem(k,np.angle(a_k)); plt.title("phase o f a_k")
plt.show()

# %% [markdown]
# Plot each component so x(t) can be represented by Fourier series representation

# %%
import numpy as np
import matplotlib.pyplot as plt

t_0 = np.arange(-3,3,0.01)
x_t = np.zeros_like(t_0,dtype = 'complex128')

N = 5 # Try to change N
for k in range(-N,N+1,1):
  # TO DO: find a_k
  x_t_k =  1j / (k * np.pi+1e-5) * np.cos(k*np.pi) * np.e**(1j * np.pi * k * t_0)
  x_t += x_t_k
  plt.plot(t_0,x_t_k,color='b'); plt.title('k = '+str(k))
  plt.show()

plt.plot(t_0,x_t,color='r')
plt.show()

# %% [markdown]
# ### CTFT

# %%
import numpy as np
import matplotlib.pyplot as plt

alpha = 4
w = np.arange(-50,50,0.01)
X_jw = 1/(alpha + 1j*w)

plt.plot(w,np.abs(X_jw))
plt.show()

plt.plot(w,np.angle(X_jw))
plt.show()

# %% [markdown]
# ## Lab 04 - CTFT + Fourier Series for DT

# %% [markdown]
# ### FT properties : Rect & Sinc

# %%
# rect(t/tau) <-> tau * sinc (w * tau / 2)
import matplotlib.pyplot as plt
import numpy as np

t = 1
tau = 1
t = np.arange(-5,5,0.01)
x_t = np.zeros_like(t)
x_t[4*100:6*100] = 1
plt.plot(t,x_t,'b')
plt.grid()
plt.show()


w = np.arange(-30,30,0.01)
X_w = tau * np.sin(w*tau/2) / (w*tau/2)
plt.plot(w,X_w,'r')
plt.grid()
plt.show()

# %% [markdown]
# * Convolution properties

# %%
len(np.arange(-5,5,0.01))
# len(y_t)

# %%
# rect(t/tau) <-> tau * sinc (w * tau / 2)
import matplotlib.pyplot as plt
import numpy as np

t = 1
tau = 1
t = np.arange(-5,5,0.01)
x_t = np.zeros_like(t)
x_t[4*100:6*100] = 1
# y_t = np.convolve(x_t,x_t)
# plt.plot(np.arange(-5,5-0.0055,0.005),y_t,'b')
y_t = np.zeros_like(x_t)
y_t[np.abs(t)<2] = 2-np.abs(t[np.abs(t)<2])
plt.plot(t,y_t)
plt.title('y_t')
plt.grid()
plt.show()


w = np.arange(-30,30,0.01)
X_w = tau * np.sin(w*tau/2) / (w*tau/2)
Y_w = X_w**2
plt.plot(w,Y_w,'r')
plt.title('Y_w')
plt.grid()
plt.show()

# %% [markdown]
# * time shifting
#
#
#   * $x(t-2) ↔ e^{-2j\omega}X(j\omega)$

# %%
# rect(t/tau) <-> tau * sinc (w * tau / 2)
import matplotlib.pyplot as plt
import numpy as np

# x(t-2)
t = 1
tau = 1
t = np.arange(-5,5,0.01)
x_t = np.zeros_like(t)
x_t[4*100+2*100:6*100+2*100] = 1
plt.plot(t,x_t,'b')
plt.grid()
plt.show()


w = np.arange(-30,30,0.01)
X_w = tau * np.sin(w*tau/2) / (w*tau/2) *np.e**(-2*1j*w)
plt.plot(w,X_w,'r')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.13/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.13/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# * frequency shifting
#
#
#   * $x(t) e^{2jt} *  ↔ X(j(\omega-2)$

# %%
# rect(t/tau) <-> tau * sinc (w * tau / 2)
import matplotlib.pyplot as plt
import numpy as np

# x(t-2)
t = 1
tau = 1
t = np.arange(-5,5,0.01)
x_t = np.zeros_like(t)
x_t[4*100+2*100:6*100+2*100] = 1
x_t = x_t * np.e**(2*1j*t) # time * complex expo
plt.plot(t,x_t,'b')
plt.grid()
plt.show()


w = np.arange(-30,30,0.01)
X_w = tau * np.sin(w*tau/2) / (w*tau/2) *np.e**(-2*1j*w)
plt.plot(w + 2,X_w,'r') # frequency shift = w-2
plt.grid()
plt.show()

# %% [markdown]
# ### Fourier series for Discrete-time signal

# %% [markdown]
# * Periodic or aperiodic

# %%
# Signal #1 Periodic?
import matplotlib.pyplot as plt
import numpy as np

k = 1
n = np.arange(-10,10,1)
x = np.e**(1j * (2 * k * np.pi)  * n/ 8) # cos + jsin
plt.stem(n,x)
plt.show()

# %%
# Signal #1 Periodic?
import matplotlib.pyplot as plt
import numpy as np

# k = 1
for k in range(16):
  n = np.arange(-10,10,1)
  x = np.real(np.e**(1j * (2 * k * np.pi)  * n/ 8)) # cos + jsin
  plt.stem(n,x)
  plt.title(k)
  plt.show()

# %%
# Signal #2 Periodic?
import matplotlib.pyplot as plt
import numpy as np

k = 1
n = np.arange(-100,100,1)
x = np.e**(1j * (2 * k )  * n/ 8)
plt.stem(n,x)
plt.show()

# %% [markdown]
# Fourier Series for Discrete-time singal Example #1

# %%
import numpy as np
import matplotlib.pyplot as plt
N = ____
N1 = ____
K = np.arange(-40,41,1)
a_k = np.zeros(K.shape)

for k in K:
  if k % N == 0:
    # Fourier Series for k = 0,+/-2Pi,...
    a_k[k-K[0]] = ___________________________
  else:
    # Fourier Series for other k
    a_k[k-K[0]] = ____________________________

plt.figure(figsize=(20,3))
plt.stem(K,a_k)

plt.show()

# %% [markdown]
# ## Lab 05
# ### Convolution
# * Linear vs. Circular
#
# * np.convolve : https://numpy.org/doc/stable/reference/generated/numpy.convolve.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,0,-1]
h = [1,3,-1,-2]
# linear convolution
y = np.convolve(h, x, mode = "full")
n = np.arange(0,len(y),1)

print(y)
plt.stem(n,y,'r',markerfmt='or')
plt.show()
# Out:
# [ 1  5  5 -5 -7  1  2]

# %%
x = [1,2,0,-1]
h = [1,3,-1,-2]

X_k = np.fft.fft(x)
H_k = np.fft.fft(h)

Y_k = X_k * H_k
y_n = np.fft.ifft(Y_k)
print(Y_k)


# print(X_k)
plt.stem(X_k)
plt.show()



print(y_n)
plt.stem(np.real(y_n))
plt.show()
# Out:
# [  2. +0.j -13.-11.j  -0. +0.j -13.+11.j]
# /usr/local/lib/python3.13/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.13/dist-packages/numpy/ma/core.py:3448: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data[indx] = dval
# /usr/local/lib/python3.13/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# [-6.+0.j  6.+0.j  7.+0.j -5.+0.j]

# %% [markdown]
# ### Circular shift
# * low-high frequency
# * calculate frequency
#   * np.fft.fftfreq()

# %%
x_n = [1,2,1,2] # N = 5
N = len(x_n)
n = np.arange(len(x_n))

X_k = np.fft.fft(x_n)

plt.stem(x_n)
plt.show()

plt.stem(np.abs(X_k),linefmt='r',markerfmt='or')
plt.show()

x_n_shift = x_n * np.e**(2j*n * 2 * np.pi / N)
X_k2 = np.fft.fft(x_n_shift)
plt.stem(np.abs(X_k2),linefmt='b',markerfmt='ob')
plt.title("Circular shift by 2 units")
plt.show()

# %% [markdown]
# ## Lab 06 - Moving Average
# * adjust M+N+1

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# moving average of M + N + 1 points
M = 20
N = 20

# total number of points
N_points = 500

# strength of noise
s_noise = 2

# strength of signal
s_signal = 10

# generate a signal
n = np.arange(N_points)
x_n = s_noise*np.random.rand(N_points) + s_signal*np.cos(2*np.pi*n/200)
plt.plot(x_n)
plt.show()

# generate the transfer function H_e_jw
w = np.linspace(-np.pi,np.pi,N_points)
H_e_jw = 1/(M+N+1)*np.e**(1j*w*(N-M)/2)*np.sin(w/2*(M+N+1))/np.sin(w/2)
plt.plot(np.abs(H_e_jw))
plt.show()

X_e_jw = np.fft.fft(x_n) # แปลง FFT x_n
plt.plot(np.abs(X_e_jw))
plt.title("fft")
plt.show()


X_e_jw = np.fft.fftshift(X_e_jw)
plt.plot(np.abs(X_e_jw))
plt.title("fft shifted")
plt.show()

# # # filtering in frequency domain
X_e_jw = np.fft.fftshift(np.fft.fft(x_n))
Y = H_e_jw * X_e_jw

# # iDFT of the output Y
y = np.fft.ifft(np.fft.ifftshift(Y))
plt.plot(np.real(y))
plt.show()
